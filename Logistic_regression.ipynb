# %% [markdown]
# <a href="https://colab.research.google.com/github/pranavsuriya-sr/MLbasics/blob/main/Logistic_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Logistic Regression - S r Pranav Suriya - CB.EN.U4ELC21050

# %% [markdown]
# Question - 1

# %%
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import mean_squared_error
# %matplotlib inline

# %%
db = pd.read_csv("/content/ques1.csv")
db
# Out:
#    Age  Insura
# 0   22       0
# 1   25       0
# 2   47       1
# 3   52       0
# 4   46       1
# 5   56       1
# 6    5       0
# 7   60       1
# 8   62       1
# 9   61       1

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(db[['Age']], db.Insura,test_size=0.1)

# %%
X_test
# Out:
#    Age
# 1   25

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
model.predict(X_test)
# Out:
# array([0])

# %% [markdown]
# Question - 2

# %%
db = pd.read_csv("/content/ques2.csv")
db
# Out:
#     Edu  Grad
# 0    14     6
# 1    12     3
# 2    16     8
# 3    13     4
# 4    15     7
# 5    11     2
# 6    17     9
# 7    12     3
# 8    18     7
# 9    14     4
# 10   20     1
# 11   15     5
# 12   11     1
# 13   17     5
# 14   13     2
# 15   14     4

# %%
X_train, X_test, y_train, y_test = train_test_split(db[['Edu']], db.Grad,test_size=0.1)
X_test
# Out:
#    Edu
# 2   16
# 6   17

# %%
model = LogisticRegression()
model.fit(X_train, y_train)
model.predict(X_test)
# Out:
# array([5, 7])

# %%
predictions = model.predict(X_test)

r2 = r2_score(y_test, predictions)
print(f"R^2 Score: {r2}")
# Out:
# R^2 Score: -0.7777777777777777

# %%
mse = mean_squared_error(y_test, predictions)
print(f"Mean Squared Error: {mse}")
# Out:
# Mean Squared Error: 4.0

# %% [markdown]
# Question - 3

# %%
db = pd.read_csv("/content/ques3.csv")
db
# Out:
#    Temp  Airqu
# 0    22     36
# 1    25     42
# 2    30     60
# 3    35     49
# 4    40     74
# 5    45     58
# 6    20     31
# 7    50     82
# 8    55     77
# 9    60     95

# %%
X_train, X_test, y_train, y_test = train_test_split(db[['Temp']], db.Airqu,test_size=0.1)
X_test
# Out:
#    Temp
# 0    22

# %%
model = LogisticRegression()
model.fit(X_train, y_train)
model.predict(X_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# array([31])

# %%
# Predict on the test set
predictions = model.predict(X_test)

# Calculate R^2 score
r2 = r2_score(y_test, predictions)
print(f"R^2 Score: {r2}")

mse = mean_squared_error(y_test, predictions)
print(f"Mean Squared Error: {mse}")
# Out:
# R^2 Score: nan
# Mean Squared Error: 25.0
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)

# %% [markdown]
# Question - 4

# %%
db = pd.read_csv("/content/ques4.csv")
db
X_train, X_test, y_train, y_test = train_test_split(db[['Salary']], db.Job,test_size=0.1)
X_test
model = LogisticRegression()
model.fit(X_train, y_train)
model.predict(X_test)
# Out:
# array([9])

# %%
db = pd.read_csv("/content/ques5.csv")
db
X_train, X_test, y_train, y_test = train_test_split(db[['Friends']], db.Social,test_size=0.1)
X_test
model = LogisticRegression()
model.fit(X_train, y_train)
model.predict(X_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# array([99])

# %%
from sklearn.metrics import confusion_matrix

predictions = model.predict(X_test)


conf_matrix = confusion_matrix(y_test, predictions)
print(conf_matrix)
# Out:
# [[0 1]
#  [0 0]]

# %%
coefficients = model.coef_
print("Coefficients:", coefficients)

intercept = model.intercept_
print("Intercept:", intercept)
# Out:
# Coefficients: [[-1.04416238]
#  [-0.64223133]
#  [-0.39322748]
#  [-0.18852308]
#  [ 0.21088132]
#  [ 0.02029688]
#  [ 0.38705855]
#  [ 0.65257502]
#  [ 0.99733252]]
# Intercept: [ 51.82726366  36.51542062  25.8512241   16.13990535  -7.30292461
#    4.65166541 -19.1160869  -38.78546429 -69.78100334]

# %%
TP = conf_matrix[1, 1]  # True Positives
TN = conf_matrix[0, 0]  # True Negatives
FP = conf_matrix[0, 1]  # False Positives
FN = conf_matrix[1, 0]  # False Negatives

print("True Positives:", TP)
print("True Negatives:", TN)
print("False Positives:", FP)
print("False Negatives:", FN)
# Out:
# True Positives: 0
# True Negatives: 0
# False Positives: 1
# False Negatives: 0
